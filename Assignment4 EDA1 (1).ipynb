# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Cardiotocographic.csv')

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.shape
# Out:
# (2126, 14)

# %%
## Missing Values

df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
## Statistical Summary

# %%
mean_values=df[['LB','AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV']].mean()

# %%
mean_values
# Out:
# LB      133.343598
# AC        0.003219
# FM        0.009894
# UC        0.004391
# DL        0.001895
# DS        0.000003
# DP        0.000175
# ASTV     46.995984
# MSTV      1.364378
# ALTV     10.285964
# MLTV      8.284887
# dtype: float64

# %%
median_values=df[['LB','AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV']].median()
median_values
# Out:
# LB      133.000000
# AC        0.001634
# FM        0.000000
# UC        0.004484
# DL        0.000000
# DS        0.000000
# DP        0.000000
# ASTV     49.000000
# MSTV      1.200000
# ALTV      0.000000
# MLTV      7.400000
# dtype: float64

# %%
std_dev=df[['LB','AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV']].std()
std_dev
# Out:
# LB      11.270154
# AC       0.004391
# FM       0.067540
# UC       0.003340
# DL       0.003343
# DS       0.000142
# DP       0.000840
# ASTV    18.813973
# MSTV     1.173632
# ALTV    21.205041
# MLTV     7.772858
# dtype: float64

# %%
q1=df[['LB','AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV']].quantile(0.25)
q3=df[['LB','AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV']].quantile(0.75)
iqr=q3-q1
print(iqr)
# Out:
# LB      14.000000
# AC       0.005650
# FM       0.002567
# UC       0.004685
# DL       0.003289
# DS       0.000000
# DP       0.000000
# ASTV    29.000000
# MSTV     1.000000
# ALTV    11.000000
# MLTV     6.300000
# dtype: float64

# %%
df[df.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2124, dtype: bool

# %%
## Data Visualization

# %%
plt.hist(df,bins=14,density=True)
plt.title('Histogram of data')
plt.show()

# %%
data=pd.DataFrame(df)

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
for column in data.columns:
    frequency=data[column].value_counts()
    print(f' Frequency of {column}:')
    print(frequency)
# Out:
#  Frequency of LB:
# LB
# 133.000000    129
# 130.000000    105
# 122.000000    102
# 138.000000     98
# 125.000000     87
#              ...
# 140.090770      1
# 123.159931      1
# 122.645790      1
# 136.142989      1
# 124.919186      1
# Name: count, Length: 153, dtype: int64
#  Frequency of AC:
# AC
# 0.000000    832
# 0.000834     13
# 0.005838      9
# 0.005004      9
# 0.002502      9
#            ...
# 0.014907      1
# 0.008006      1
# 0.012431      1
# 0.011986      1
# 0.001616      1
# Name: count, Length: 1067, dtype: int64
#  Frequency of FM:
# FM
#  0.000000    1230
#  0.000834      10
#  0.001668       9
#  0.003336       9
#  0.005838       7
#              ...
#  0.001229       1
#  0.028708       1
#  0.002894       1
# -0.000519       1
# -0.000188       1
# Name: count, Length: 776, dtype: int64
#  Frequency of UC:
# UC
# 0.000000    317
# 0.000834     24
# 0.001668     15
# 0.002502     12
# 0.004170     10
#            ...
# 0.008287      1
# ...

# %%
for column in data.columns:
    categories=data[column].unique()
    print(f' Categories of {column}:')
    print(categories)
# Out:
#  Categories of LB:
# [120.         132.         133.         134.         131.94823162
#  122.         151.         150.         131.         130.
#  129.         128.         124.         115.         114.
#  116.         158.                  nan 156.         147.81657385
#  149.         146.         148.         144.         142.
#  136.         141.         138.         140.         154.
#  145.         144.93508565 139.         125.         123.
#  159.         158.75766557  52.         143.         148.96141613
#  119.         118.9736874  121.         137.8325398  123.78909453
#  127.         128.84390776 125.14358925 124.62776778 123.3350051
#  125.80994939 126.         118.         135.         144.34576434
#  146.00059107 137.         134.72723786 133.28233138 137.82451993
#  140.52416935 149.95442235 147.         214.         136.66065106
#  125.12265281 151.17863367 157.         156.86235589 128.3759678
#  143.45812176 142.11653388 143.94636332 136.14298944 122.64579013
# ...

# %%
sns.violinplot(data=df,y='LB',x='AC')
# Out:
# <Axes: xlabel='AC', ylabel='LB'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2124 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2103 non-null   float64
#  1   AC        2104 non-null   float64
#  2   FM        2124 non-null   float64
#  3   UC        2124 non-null   float64
#  4   DL        2124 non-null   float64
#  5   DS        2103 non-null   float64
#  6   DP        2103 non-null   float64
#  7   ASTV      2124 non-null   float64
#  8   MSTV      2124 non-null   float64
#  9   ALTV      2124 non-null   float64
#  10  MLTV      2103 non-null   float64
#  11  Width     2103 non-null   float64
#  12  Tendency  2103 non-null   float64
#  13  NSP       2103 non-null   float64
# dtypes: float64(14)
# memory usage: 248.9 KB
