# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder
from sklearn.ensemble import IsolationForest

# %%
# Load the dataset
data=pd.read_csv('adult_with_headers.csv')

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ## 1.Data Exploration and Preprocessing

# %%
# Check for invalid placeholders and replace '?' with NaN

# %%
data_cleaned=data.replace('?',np.nan)

# %%
data_cleaned
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
# Handle Missing values by removing rows with missing data
data_cleaned.dropna(inplace=True)

# %%
data_cleaned
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
# Display summery Statistics
def summarize_data(df):
    print('\n Summary Statistics:')
    print(df.describe(include='all'))
    print('\n Missing Values:')
    print(df.isnull().sum())

summarize_data(data_cleaned)
# Out:
#  Summary Statistics:
#                  age workclass        fnlwgt education  education_num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              marital_status       occupation relationship    race    sex  \
# count                 32561            32561        32561   32561  32561
# unique                    7               15            6       5      2
# top      Married-civ-spouse   Prof-specialty      Husband   White   Male
# freq                  14976             4140        13193   27816  21790
# mean                    NaN              NaN          NaN     NaN    NaN
# std                     NaN              NaN          NaN     NaN    NaN
# min                     NaN              NaN          NaN     NaN    NaN
# 25%                     NaN              NaN          NaN     NaN    NaN
# 50%                     NaN              NaN          NaN     NaN    NaN
# 75%                     NaN              NaN          NaN     NaN    NaN
# max                     NaN              NaN          NaN     NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week  native_country  income
# count   32561.000000  32561.000000    32561.000000           32561   32561
# unique           NaN           NaN             NaN              42       2
# top              NaN           NaN             NaN   United-States   <=50K
# freq             NaN           NaN             NaN           29170   24720
# mean     1077.648844     87.303830       40.437456             NaN     NaN
# std      7385.292085    402.960219       12.347429             NaN     NaN
# min         0.000000      0.000000        1.000000             NaN     NaN
# 25%         0.000000      0.000000       40.000000             NaN     NaN
# 50%         0.000000      0.000000       40.000000             NaN     NaN
# 75%         0.000000      0.000000       45.000000             NaN     NaN
# max     99999.000000   4356.000000       99.000000             NaN     NaN
#
#  Missing Values:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Scaling numerical features
numerical_cols=['age','fnlwgt','education_num','hours_per_week']
scaler_standard=StandardScaler()
scaler_minmax=MinMaxScaler()

# %%
# Perform scaling before modifying numerical columns
data_cleaned_standard_scaled = pd.DataFrame(
    scaler_standard.fit_transform(data_cleaned[numerical_cols]),
    columns=[f"{col}_standard" for col in numerical_cols]
)

data_cleaned_minmax_scaled = pd.DataFrame(
    scaler_minmax.fit_transform(data_cleaned[numerical_cols]),
    columns=[f"{col}_minmax" for col in numerical_cols]
)

# %%
# Combine Scaled data back with the original dataset
data_cleaned=pd.concat([data_cleaned,data_cleaned_standard_scaled,data_cleaned_minmax_scaled],axis=1)

# %%
data_cleaned
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  ...  native_country  income  age_standard fnlwgt_standard  \
# 0         Male  ...   United-States   <=50K      0.030671       -1.063611
# 1         Male  ...   United-States   <=50K      0.837109       -1.008707
# 2         Male  ...   United-States   <=50K     -0.042642        0.245079
# 3         Male  ...   United-States   <=50K      1.057047        0.425801
# 4       Female  ...            Cuba   <=50K     -0.775768        1.408176
# ...        ...  ...             ...     ...           ...             ...
# 32556   Female  ...   United-States   <=50K     -0.849080        0.639741
# 32557     Male  ...   United-States    >50K      0.103983       -0.335433
# 32558   Female  ...   United-States   <=50K      1.423610       -0.358777
# 32559     Male  ...   United-States   <=50K     -1.215643        0.110960
# 32560   Female  ...   United-States    >50K      0.983734        0.929893
#
#       education_num_standard  hours_per_week_standard  age_minmax  \
# 0                   1.134739                -0.035429    0.301370
# 1                   1.134739                -2.222153    0.452055
# 2                  -0.420060                -0.035429    0.287671
# 3                  -1.197459                -0.035429    0.493151
# 4                   1.134739                -0.035429    0.150685
# ...                      ...                      ...         ...
# 32556               0.746039                -0.197409    0.136986
# 32557              -0.420060                -0.035429    0.315068
# 32558              -0.420060                -0.035429    0.561644
# 32559              -0.420060                -1.655225    0.068493
# 32560              -0.420060                -0.035429    0.479452
#
#        fnlwgt_minmax  education_num_minmax  hours_per_week_minmax
# 0           0.044302              0.800000               0.397959
# 1           0.048238              0.800000               0.122449
# 2           0.138113              0.533333               0.397959
# 3           0.151068              0.400000               0.397959
# 4           0.221488              0.800000               0.397959
# ...              ...                   ...                    ...
# 32556       0.166404              0.733333               0.377551
# 32557       0.096500              0.533333               0.397959
# 32558       0.094827              0.533333               0.397959
# 32559       0.128499              0.533333               0.193878
# 32560       0.187203              0.533333               0.397959
#
# [32561 rows x 23 columns]

# %%
## Discuss the scenarios where each scaling technique is preferred and why.
#Scaling Techniques: Scenarios and Preferences
#Standard Scaling:
#Scenario: Data follows a normal distribution or is assumed to be approximately Gaussian.
#Why: Standard scaling centers data around a mean of 0 with a standard deviation of 1, which is ideal for algorithms like Support Vector Machines (SVM) and Principal Component Analysis (PCA) that are sensitive to feature magnitudes.

#Min-Max Scaling:
#Scenario: Data needs to be normalized to a fixed range (e.g., [0, 1]) or when working with algorithms that don't assume a normal distribution (e.g., Neural Networks, KNN).
#Why: Min-Max Scaling preserves the data's original distribution while transforming values into a uniform range, which helps avoid dominance of large magnitude features. It’s also useful when feature scaling is required for bounded inputs like image pixel intensities.

# %% [markdown]
# ## 2.Encoding Techniques

# %%
# Identify Categorical Columns
categorical_cols=data_cleaned.select_dtypes(include=['object']).columns

# %%
categorical_cols
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='object')

# %%
# Apply One_hot encoding for variables with <5 categories
one_hot_cols=[col for col in categorical_cols if data_cleaned[col].nunique()<5]
data_cleaned=pd.get_dummies(data_cleaned,columns=one_hot_cols,drop_first=True)

# %%
# Apply Label Encoding for variables with>=5 categories
label_encoder = LabelEncoder()
label_columns = [col for col in categorical_cols if col not in one_hot_cols]
for col in label_columns:
    data_cleaned[col] = label_encoder.fit_transform(data_cleaned[col])

# %%
data_cleaned
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  capital_gain  ...  age_standard  \
# 0               1             1     4          2174  ...      0.030671
# 1               4             0     4             0  ...      0.837109
# 2               6             1     4             0  ...     -0.042642
# 3               6             0     2             0  ...      1.057047
# 4              10             5     2             0  ...     -0.775768
# ...           ...           ...   ...           ...  ...           ...
# 32556          13             5     4             0  ...     -0.849080
# 32557           7             0     4             0  ...      0.103983
# 32558           1             4     4             0  ...      1.423610
# 32559           1             3     4             0  ...     -1.215643
# 32560           4             5     4         15024  ...      0.983734
#
#        fnlwgt_standard  education_num_standard  hours_per_week_standard  \
# 0            -1.063611                1.134739                -0.035429
# 1            -1.008707                1.134739                -2.222153
# 2             0.245079               -0.420060                -0.035429
# 3             0.425801               -1.197459                -0.035429
# 4             1.408176                1.134739                -0.035429
# ...                ...                     ...                      ...
# 32556         0.639741                0.746039                -0.197409
# 32557        -0.335433               -0.420060                -0.035429
# 32558        -0.358777               -0.420060                -0.035429
# 32559         0.110960               -0.420060                -1.655225
# 32560         0.929893               -0.420060                -0.035429
#
#        age_minmax  fnlwgt_minmax  education_num_minmax  hours_per_week_minmax  \
# 0        0.301370       0.044302              0.800000               0.397959
# 1        0.452055       0.048238              0.800000               0.122449
# 2        0.287671       0.138113              0.533333               0.397959
# 3        0.493151       0.151068              0.400000               0.397959
# 4        0.150685       0.221488              0.800000               0.397959
# ...           ...            ...                   ...                    ...
# 32556    0.136986       0.166404              0.733333               0.377551
# 32557    0.315068       0.096500              0.533333               0.397959
# 32558    0.561644       0.094827              0.533333               0.397959
# 32559    0.068493       0.128499              0.533333               0.193878
# 32560    0.479452       0.187203              0.533333               0.397959
#
#        sex_ Male  income_ >50K
# 0           True         False
# 1           True         False
# 2           True         False
# 3           True         False
# 4          False         False
# ...          ...           ...
# 32556      False         False
# 32557       True          True
# 32558      False         False
# 32559       True         False
# 32560      False          True
#
# [32561 rows x 23 columns]

# %%
##•	Discuss the pros and cons of One-Hot Encoding and Label Encoding.
# One-Hot Encoding:
#Pros:
#No Ordinal Relationship Assumed: Treats each category as a separate entity, making it useful when no inherent order exists.
#Prevents Model Bias: Each category gets equal weight in the model, reducing bias.
#Versatility: Works well with many machine learning models like decision trees, linear models, and neural networks.
#Cons:
#High Dimensionality: For categories with many levels, it leads to a large number of features, which can increase computational cost and risk overfitting.
#Sparsity: Many zeros in the feature matrix, which can make storage inefficient.

##Label Encoding:
#Pros:
#Efficient Storage: Converts categories into a smaller range of integers, leading to lower dimensionality.
#Simple and Fast: Easier to implement and computationally efficient.
#Cons:
#Imposes Ordinality: May mislead the model into thinking that there's a rank or order to the categories, which is not always correct.
#Not Suitable for Non-Ordinal Categories: If the categories are nominal (no order), label encoding may cause inaccurate relationships in models.

# %% [markdown]
# ## 3.Feature Engineering

# %%
# Create two new features
data_cleaned['capital_diff'] = data_cleaned['capital_gain'] - data_cleaned['capital_loss']
data_cleaned['hours_per_week_bins'] = pd.cut(data_cleaned['hours_per_week'], bins=[0, 20, 40, 60, 100], labels=['Low', 'Medium', 'High', 'Very High'])

# %%
# Apply a log transformation to skewed features
data_cleaned['capital_gain_log'] = np.log1p(data_cleaned['capital_gain'])

# %% [markdown]
# ## 4.Feature Seletion

# %%
# Isolation Forest for outlier detection
iso_forest = IsolationForest(contamination=0.01, random_state=42)
outlier_preds = iso_forest.fit_predict(data_cleaned[numerical_cols])

# %%
outlier_preds
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Remove Outliers
data_cleaned=data_cleaned[outlier_preds==1]

# %%
data_cleaned
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  capital_gain  ...  \
# 0               1             1     4          2174  ...
# 1               4             0     4             0  ...
# 2               6             1     4             0  ...
# 3               6             0     2             0  ...
# 4              10             5     2             0  ...
# ...           ...           ...   ...           ...  ...
# 32556          13             5     4             0  ...
# 32557           7             0     4             0  ...
# 32558           1             4     4             0  ...
# 32559           1             3     4             0  ...
# 32560           4             5     4         15024  ...
#
#        hours_per_week_standard  age_minmax  fnlwgt_minmax  \
# 0                    -0.035429    0.301370       0.044302
# 1                    -2.222153    0.452055       0.048238
# 2                    -0.035429    0.287671       0.138113
# 3                    -0.035429    0.493151       0.151068
# 4                    -0.035429    0.150685       0.221488
# ...                        ...         ...            ...
# 32556                -0.197409    0.136986       0.166404
# 32557                -0.035429    0.315068       0.096500
# 32558                -0.035429    0.561644       0.094827
# 32559                -1.655225    0.068493       0.128499
# 32560                -0.035429    0.479452       0.187203
#
#        education_num_minmax  hours_per_week_minmax  sex_ Male  income_ >50K  \
# 0                  0.800000               0.397959       True         False
# 1                  0.800000               0.122449       True         False
# 2                  0.533333               0.397959       True         False
# 3                  0.400000               0.397959       True         False
# 4                  0.800000               0.397959      False         False
# ...                     ...                    ...        ...           ...
# 32556              0.733333               0.377551      False         False
# 32557              0.533333               0.397959       True          True
# 32558              0.533333               0.397959      False         False
# 32559              0.533333               0.193878       True         False
# 32560              0.533333               0.397959      False          True
#
#        capital_diff  hours_per_week_bins  capital_gain_log
# 0              2174               Medium          7.684784
# 1                 0                  Low          0.000000
# 2                 0               Medium          0.000000
# 3                 0               Medium          0.000000
# 4                 0               Medium          0.000000
# ...             ...                  ...               ...
# 32556             0               Medium          0.000000
# 32557             0               Medium          0.000000
# 32558             0               Medium          0.000000
# 32559             0                  Low          0.000000
# 32560         15024               Medium          9.617471
#
# [32235 rows x 26 columns]

# %%
# Correlation matrix analysis
# Ensure only numeric columns are used for correlation
numeric_cols = data_cleaned.select_dtypes(include=[np.number]).columns
correlation_matrix = data_cleaned[numeric_cols].corr()
correlation_matrix_filtered = correlation_matrix[(correlation_matrix > 0.2) | (correlation_matrix < -0.2)]

# %%
# Output results
print("\nFiltered Correlation Matrix:")
print(correlation_matrix_filtered)
# Out:
# Filtered Correlation Matrix:
#                               age  workclass  fnlwgt  education  \
# age                      1.000000        NaN     NaN        NaN
# workclass                     NaN   1.000000     NaN        NaN
# fnlwgt                        NaN        NaN     1.0        NaN
# education                     NaN        NaN     NaN   1.000000
# education_num                 NaN        NaN     NaN   0.349249
# marital_status          -0.282289        NaN     NaN        NaN
# occupation                    NaN   0.247565     NaN        NaN
# relationship            -0.264710        NaN     NaN        NaN
# race                          NaN        NaN     NaN        NaN
# capital_gain                  NaN        NaN     NaN        NaN
# capital_loss                  NaN        NaN     NaN        NaN
# hours_per_week                NaN        NaN     NaN        NaN
# native_country                NaN        NaN     NaN        NaN
# age_standard             1.000000        NaN     NaN        NaN
# fnlwgt_standard               NaN        NaN     1.0        NaN
# education_num_standard        NaN        NaN     NaN   0.349249
# hours_per_week_standard       NaN        NaN     NaN        NaN
# age_minmax               1.000000        NaN     NaN        NaN
# fnlwgt_minmax                 NaN        NaN     1.0        NaN
# education_num_minmax          NaN        NaN     NaN   0.349249
# hours_per_week_minmax         NaN        NaN     NaN        NaN
# capital_diff                  NaN        NaN     NaN        NaN
# capital_gain_log              NaN        NaN     NaN        NaN
#
#                          education_num  marital_status  occupation  \
# age                                NaN       -0.282289         NaN
# workclass                          NaN             NaN    0.247565
# fnlwgt                             NaN             NaN         NaN
# education                     0.349249             NaN         NaN
# education_num                 1.000000             NaN         NaN
# marital_status                     NaN        1.000000         NaN
# occupation                         NaN             NaN    1.000000
# relationship                       NaN             NaN         NaN
# race                               NaN             NaN         NaN
# capital_gain                       NaN             NaN         NaN
# capital_loss                       NaN             NaN         NaN
# hours_per_week                     NaN             NaN         NaN
# native_country                     NaN             NaN         NaN
# age_standard                       NaN       -0.282289         NaN
# fnlwgt_standard                    NaN             NaN         NaN
# education_num_standard        1.000000             NaN         NaN
# hours_per_week_standard            NaN             NaN         NaN
# age_minmax                         NaN       -0.282289         NaN
# fnlwgt_minmax                      NaN             NaN         NaN
# education_num_minmax          1.000000             NaN         NaN
# hours_per_week_minmax              NaN             NaN         NaN
# capital_diff                       NaN             NaN         NaN
# capital_gain_log                   NaN             NaN         NaN
#
#                          relationship  race  capital_gain  ...  age_standard  \
# age                         -0.264710   NaN           NaN  ...      1.000000
# workclass                         NaN   NaN           NaN  ...           NaN
# fnlwgt                            NaN   NaN           NaN  ...           NaN
# education                         NaN   NaN           NaN  ...           NaN
# education_num                     NaN   NaN           NaN  ...           NaN
# marital_status                    NaN   NaN           NaN  ...     -0.282289
# occupation                        NaN   NaN           NaN  ...           NaN
# relationship                 1.000000   NaN           NaN  ...     -0.264710
# race                              NaN   1.0           NaN  ...           NaN
# capital_gain                      NaN   NaN      1.000000  ...           NaN
# capital_loss                      NaN   NaN           NaN  ...           NaN
# hours_per_week              -0.258436   NaN           NaN  ...           NaN
# native_country                    NaN   NaN           NaN  ...           NaN
# age_standard                -0.264710   NaN           NaN  ...      1.000000
# fnlwgt_standard                   NaN   NaN           NaN  ...           NaN
# education_num_standard            NaN   NaN           NaN  ...           NaN
# hours_per_week_standard     -0.258436   NaN           NaN  ...           NaN
# age_minmax                  -0.264710   NaN           NaN  ...      1.000000
# fnlwgt_minmax                     NaN   NaN           NaN  ...           NaN
# education_num_minmax              NaN   NaN           NaN  ...           NaN
# hours_per_week_minmax       -0.258436   NaN           NaN  ...           NaN
# capital_diff                      NaN   NaN      0.998527  ...           NaN
# capital_gain_log                  NaN   NaN      0.564370  ...           NaN
#
#                          fnlwgt_standard  education_num_standard  \
# age                                  NaN                     NaN
# workclass                            NaN                     NaN
# fnlwgt                               1.0                     NaN
# education                            NaN                0.349249
# education_num                        NaN                1.000000
# marital_status                       NaN                     NaN
# occupation                           NaN                     NaN
# relationship                         NaN                     NaN
# race                                 NaN                     NaN
# capital_gain                         NaN                     NaN
# capital_loss                         NaN                     NaN
# hours_per_week                       NaN                     NaN
# native_country                       NaN                     NaN
# age_standard                         NaN                     NaN
# fnlwgt_standard                      1.0                     NaN
# education_num_standard               NaN                1.000000
# hours_per_week_standard              NaN                     NaN
# age_minmax                           NaN                     NaN
# fnlwgt_minmax                        1.0                     NaN
# education_num_minmax                 NaN                1.000000
# hours_per_week_minmax                NaN                     NaN
# capital_diff                         NaN                     NaN
# capital_gain_log                     NaN                     NaN
#
#                          hours_per_week_standard  age_minmax  fnlwgt_minmax  \
# age                                          NaN    1.000000            NaN
# workclass                                    NaN         NaN            NaN
# fnlwgt                                       NaN         NaN            1.0
# education                                    NaN         NaN            NaN
# education_num                                NaN         NaN            NaN
# marital_status                               NaN   -0.282289            NaN
# occupation                                   NaN         NaN            NaN
# relationship                           -0.258436   -0.264710            NaN
# race                                         NaN         NaN            NaN
# capital_gain                                 NaN         NaN            NaN
# capital_loss                                 NaN         NaN            NaN
# hours_per_week                          1.000000         NaN            NaN
# native_country                               NaN         NaN            NaN
# age_standard                                 NaN    1.000000            NaN
# fnlwgt_standard                              NaN         NaN            1.0
# education_num_standard                       NaN         NaN            NaN
# hours_per_week_standard                 1.000000         NaN            NaN
# age_minmax                                   NaN    1.000000            NaN
# fnlwgt_minmax                                NaN         NaN            1.0
# education_num_minmax                         NaN         NaN            NaN
# hours_per_week_minmax                   1.000000         NaN            NaN
# capital_diff                                 NaN         NaN            NaN
# capital_gain_log                             NaN         NaN            NaN
#
#                          education_num_minmax  hours_per_week_minmax  \
# age                                       NaN                    NaN
# workclass                                 NaN                    NaN
# fnlwgt                                    NaN                    NaN
# education                            0.349249                    NaN
# education_num                        1.000000                    NaN
# marital_status                            NaN                    NaN
# occupation                                NaN                    NaN
# relationship                              NaN              -0.258436
# race                                      NaN                    NaN
# capital_gain                              NaN                    NaN
# capital_loss                              NaN                    NaN
# hours_per_week                            NaN               1.000000
# native_country                            NaN                    NaN
# age_standard                              NaN                    NaN
# fnlwgt_standard                           NaN                    NaN
# education_num_standard               1.000000                    NaN
# hours_per_week_standard                   NaN               1.000000
# age_minmax                                NaN                    NaN
# fnlwgt_minmax                             NaN                    NaN
# education_num_minmax                 1.000000                    NaN
# hours_per_week_minmax                     NaN               1.000000
# capital_diff                              NaN                    NaN
# capital_gain_log                          NaN                    NaN
#
#                          capital_diff  capital_gain_log
# age                               NaN               NaN
# workclass                         NaN               NaN
# fnlwgt                            NaN               NaN
# education                         NaN               NaN
# education_num                     NaN               NaN
# marital_status                    NaN               NaN
# occupation                        NaN               NaN
# relationship                      NaN               NaN
# race                              NaN               NaN
# capital_gain                 0.998527          0.564370
# capital_loss                      NaN               NaN
# hours_per_week                    NaN               NaN
# native_country                    NaN               NaN
# age_standard                      NaN               NaN
# fnlwgt_standard                   NaN               NaN
# education_num_standard            NaN               NaN
# hours_per_week_standard           NaN               NaN
# age_minmax                        NaN               NaN
# fnlwgt_minmax                     NaN               NaN
# education_num_minmax              NaN               NaN
# hours_per_week_minmax             NaN               NaN
# capital_diff                 1.000000          0.566088
# capital_gain_log             0.566088          1.000000
#
# [23 rows x 23 columns]
